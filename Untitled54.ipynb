# %% [markdown]
# <a href="https://colab.research.google.com/github/peterbmob/DHMVADoE/blob/main/Untitled54.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data=pd.read_excel('DATA.xlsx', index_col=0)
# Out:
#        m.kat  v.ml   m.add   T  p.h2  p.co2  t.h     ton.dmm      ton.mf
# obsnr
# 1      1.500  0.50  6.2500  20    60     20   18    3.856333   48.735111
# 2      1.500  0.50  6.2500  20    60     20   18    7.377333   45.773000
# 3      1.500  0.50  6.2500  20    60     20   18   12.826500   58.683333
# 4      1.500  0.50  6.2500  70    60     20   18  154.421000  164.816333
# 5      1.500  0.50  6.2500  70    60     20   18  155.678500  162.916111
# ...      ...   ...     ...  ..   ...    ...  ...         ...         ...
# 140    0.000  0.50  6.2500  90    90     20   18    0.000000    4.582889
# 141    0.000  0.50  6.2500  90    90     20   18    0.503000    5.477111
# 142    0.375  0.25  1.5625  90    90     20   18  604.103000  204.106222
# 143    0.375  0.25  1.5625  90    90     20   18  616.342667  188.457333
# 144    0.375  0.25  1.5625  90    90     20   18  631.097333  195.499333
#
# [144 rows x 9 columns]

# %%
input_label.values()
# Out:
# dict_values(['m.kat', 'v.ml', 'm.add', 'T', 'p.h2', 'p.co2', 't.h', 'ton.dmm', 'ton.mf'])

# %%
import string
alphabet = list(string.ascii_uppercase)
count=-1
inputs_labels={}
for column in data.columns:
  count += 1
  inputs_labels[alphabet[count]]=data.columns[count]

dat=[]
for key, value in zip(input_label.keys(), input_label.values()):
  dat.append([key, data.loc[:,value].min(),data.loc[:,value].max()])


# create pandas dataframe in a pandas dataframe
inputs_df = pd.DataFrame(dat,columns=['index','low','high'])
inputs_df = inputs_df.set_index(['index'])
inputs_df['label'] = inputs_df.index.map( lambda z : inputs_labels[z] )

#print dataframe
inputs_df
# Out:
#          low         high    label
# index
# A       0.00     3.000000    m.kat
# B       0.25     0.500000     v.ml
# C       0.00    12.500000    m.add
# D      20.00   120.000000        T
# E      40.00   100.000000     p.h2
# F       5.00    40.000000    p.co2
# G       1.00   168.000000      t.h
# H       0.00   906.406000  ton.dmm
# I       0.00  1376.655111   ton.mf

# %%
# compute averages and span
inputs_df['average'] = inputs_df.apply( lambda z : ( z['high'] + z['low'])/2 , axis=1)
inputs_df['span'] = inputs_df.apply( lambda z : ( z['high'] - z['low'])/2 , axis=1)

# encode the data
inputs_df['encoded_low'] = inputs_df.apply( lambda z : ( z['low']  - z['average'] )/( z['span'] ), axis=1)
inputs_df['encoded_high'] = inputs_df.apply( lambda z : ( z['high'] - z['average'] )/( z['span'] ), axis=1)

inputs_df = inputs_df.drop(['average','span'],axis=1)

inputs_df
# Out:
#          low         high    label  encoded_low  encoded_high
# index
# A       0.00     3.000000    m.kat         -1.0           1.0
# B       0.25     0.500000     v.ml         -1.0           1.0
# C       0.00    12.500000    m.add         -1.0           1.0
# D      20.00   120.000000        T         -1.0           1.0
# E      40.00   100.000000     p.h2         -1.0           1.0
# F       5.00    40.000000    p.co2         -1.0           1.0
# G       1.00   168.000000      t.h         -1.0           1.0
# H       0.00   906.406000  ton.dmm         -1.0           1.0
# I       0.00  1376.655111   ton.mf         -1.0           1.0

# %%
inputs_df.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I'], dtype='object', name='index')

# %%
encoded_data=pd.DataFrame({})
X_real=data.loc[:,'m.kat':'t.h']
for key, column in zip(inputs_df.index, X_real.columns):
  average= (inputs_df['high'].loc[key] + inputs_df['low'].loc[key])/2
  span =  (inputs_df['high'].loc[key] - inputs_df['low'].loc[key])/2
  encodedlist=[]
  for i in range(0,len(data)):
    encodedlist.append((X_real[column].iloc[i] - average)/span)
  encoded_data[column]= encodedlist

encoded_data
# Out:
#      m.kat  v.ml  m.add    T      p.h2     p.co2       t.h
# 0     0.00   1.0   0.00 -1.0 -0.333333 -0.142857 -0.796407
# 1     0.00   1.0   0.00 -1.0 -0.333333 -0.142857 -0.796407
# 2     0.00   1.0   0.00 -1.0 -0.333333 -0.142857 -0.796407
# 3     0.00   1.0   0.00  0.0 -0.333333 -0.142857 -0.796407
# 4     0.00   1.0   0.00  0.0 -0.333333 -0.142857 -0.796407
# ..     ...   ...    ...  ...       ...       ...       ...
# 139  -1.00   1.0   0.00  0.4  0.666667 -0.142857 -0.796407
# 140  -1.00   1.0   0.00  0.4  0.666667 -0.142857 -0.796407
# 141  -0.75  -1.0  -0.75  0.4  0.666667 -0.142857 -0.796407
# 142  -0.75  -1.0  -0.75  0.4  0.666667 -0.142857 -0.796407
# 143  -0.75  -1.0  -0.75  0.4  0.666667 -0.142857 -0.796407
#
# [144 rows x 7 columns]

# %%
# Out:
# <Axes: >

# %%
doe1 = encoded_data[encoded_data['m.kat']==-1]

# %%
doe1
# Out:
#      m.kat  v.ml  m.add    T      p.h2     p.co2       t.h
# 135   -1.0   1.0   -1.0  0.4  0.666667 -0.142857 -0.796407
# 136   -1.0   1.0   -1.0  0.4  0.666667 -0.142857 -0.796407
# 139   -1.0   1.0    0.0  0.4  0.666667 -0.142857 -0.796407
# 140   -1.0   1.0    0.0  0.4  0.666667 -0.142857 -0.796407

# %% [markdown]
# https://pubs.rsc.org/en/content/articlelanding/2019/sc/c9sc04591k#!divAbstract
